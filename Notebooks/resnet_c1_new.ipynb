# %%
# !pip install timm
# Out:
# Requirement already satisfied: timm in /Users/rubyjiang/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages (0.5.4)
# Requirement already satisfied: torch>=1.4 in /Users/rubyjiang/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages (from timm) (1.11.0)
# Requirement already satisfied: torchvision in /Users/rubyjiang/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages (from timm) (0.12.0)
# Requirement already satisfied: typing-extensions in /Users/rubyjiang/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages (from torch>=1.4->timm) (4.1.1)
# Requirement already satisfied: numpy in /Users/rubyjiang/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages (from torchvision->timm) (1.19.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/rubyjiang/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages (from torchvision->timm) (8.4.0)
# Requirement already satisfied: requests in /Users/rubyjiang/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages (from torchvision->timm) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rubyjiang/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages (from requests->torchvision->timm) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rubyjiang/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages (from requests->torchvision->timm) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/rubyjiang/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages (from requests->torchvision->timm) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rubyjiang/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages (from requests->torchvision->timm) (1.26.9)

# %%
from functools import partial
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
from timm.models.layers import trunc_normal_, DropPath
from timm.models.registry import register_model
import tarfile

from numpy import identity
import torch
import torch.nn as  nn
import torch.nn.functional as F
from timm.models.layers import DropPath

from torchsummary import summary

# %%
class LayerNorm(nn.Module):
    r""" LayerNorm that supports two data formats: channels_last (default) or channels_first. 
    The ordering of the dimensions in the inputs. channels_last corresponds to inputs with 
    shape (batch_size, height, width, channels) while channels_first corresponds to inputs 
    with shape (batch_size, channels, height, width).
    """
    def __init__(self, normalized_shape, eps=1e-6, data_format="channels_last"):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(normalized_shape))
        self.bias = nn.Parameter(torch.zeros(normalized_shape))
        self.eps = eps
        self.data_format = data_format
        if self.data_format not in ["channels_last", "channels_first"]:
            raise NotImplementedError 
        self.normalized_shape = (normalized_shape, )
    
    def forward(self, x):
        if self.data_format == "channels_last":
            return F.layer_norm(x, self.normalized_shape, self.weight, self.bias, self.eps)
        elif self.data_format == "channels_first":
            u = x.mean(1, keepdim=True)
            s = (x - u).pow(2).mean(1, keepdim=True)
            x = (x - u) / torch.sqrt(s + self.eps)
            x = self.weight[:, None, None] * x + self.bias[:, None, None]
            return x

# %%
 ### The bottleneck that works
# class Bottleneck(nn.Module):
#     def __init__(self, in_channels, out_channels, drop_path=0, stride=1):
#         super().__init__()

#         self.expansion = 4
        
#         self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, padding=0, bias=False)
#         self.bn1 = nn.BatchNorm2d(out_channels)
#         self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
#         self.bn2 = nn.BatchNorm2d(out_channels)
#         self.conv3 = nn.Conv2d(out_channels, self.expansion*out_channels, kernel_size=1, stride=1, padding=0, bias=False)
#         self.bn3 = nn.BatchNorm2d(self.expansion*out_channels)
        
#         self.relu = nn.ReLU()
        
#         self.drop_path = DropPath(drop_path) if drop_path > 0 else nn.Identity()
    
#     def forward(self, x):

#         identity = x.clone()

#         x = self.conv1(x)
#         x = self.bn1(x)
#         x = self.relu(x)

#         x = self.conv2(x)
#         x = self.bn2(x)
#         x = self.relu(x)

#         x = self.conv3(x)
#         x = self.bn3(x)
        
#         #x = self.drop_path(x) + identity
#         x = self.drop_path(x)
#         x = self.relu(x)
        
#         return x

# %%
class Bottleneck(nn.Module):
    def __init__(self, in_channels, out_channels, drop_path=0, stride=1, first=False):
        super().__init__()

        self.expansion = 4
        
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, padding=0, bias=False)
        #self.bn1 = nn.BatchNorm2d(out_channels)
        self.layer_norm = LayerNorm(out_channels, eps=1e-6, data_format="channels_first")
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        #self.bn2 = nn.BatchNorm2d(out_channels)
        self.conv3 = nn.Conv2d(out_channels, self.expansion*out_channels, kernel_size=1, stride=1, padding=0, bias=False)
        #self.bn3 = nn.BatchNorm2d(self.expansion*out_channels)
        
        self.gelu = nn.GELU()
        
        self.drop_path = DropPath(drop_path) if drop_path > 0 else nn.Identity()
        
        self.first = first
        self.conv_skip = nn.Conv2d(in_channels,  self.expansion*out_channels, kernel_size=1, stride=1, padding=0, bias=False)
    
    def forward(self, x):

        identity = x.clone()
        if self.first:
            identity = self.conv_skip(x)

        x = self.conv1(x)
        x = self.bn1(x)
        x = self.layer_norm(x)
        #x = self.relu(x)

        x = self.conv2(x)
        #x = self.bn2(x)
        x = self.gelu(x)

        x = self.conv3(x)
        #x = self.bn3(x)
        
        x = self.drop_path(x) + identity
        #x = self.relu(x)
        
        return x

# %%
class ResNet(nn.Module):
    def __init__(self, block=Bottleneck, depths = [3,4,6,3], dims=[64, 128, 256, 512], num_classes=7000, in_channels=3, drop_path=0.0):
        super().__init__()

        self.expansion = 4
        self.inplanes = 64
        
        # 4 downsample layers
        self.downsample_layers = nn.ModuleList() # stem and 3 intermediate downsampling conv layers
        stem = nn.Sequential(
#             nn.Conv2d(in_chans, dims[0], kernel_size=4, stride=4),
#             LayerNorm(dims[0], eps=1e-6, data_format="channels_first")
            nn.Conv2d(in_channels, 64, kernel_size=7, stride=2, padding=3, bias=False),
            LayerNorm(64, eps=1e-6, data_format="channels_first"),#nn.BatchNorm2d(64),
            nn.GELU(), #nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )
        self.downsample_layers.append(stem)
        # the rest 3 downsampling layers
        for i in range(3):
            downsample_layer = nn.Sequential(
                    LayerNorm(dims[i]*self.expansion, eps=1e-6, data_format="channels_first"),
                    nn.Conv2d(dims[i]*self.expansion, dims[i]*self.expansion, kernel_size=2, stride=2),
            )
            self.downsample_layers.append(downsample_layer)
        
        
        # 4 stages
        drop_path_rates = [x.item() for x in torch.linspace(0, drop_path, sum(depths))] 
        self.stages = nn.ModuleList() # 4 feature resolution stages, each consisting of multiple residual blocks
        self.stage1 = self.make_stage(block, depths[0], dims[0], drop_path=drop_path_rates[0:depths[0]], stride=1)
        self.stage2 = self.make_stage(block, depths[1], dims[1], drop_path=drop_path_rates[depths[0]:sum(depths[:2])], stride=1)
        self.stage3 = self.make_stage(block, depths[2], dims[2], drop_path=drop_path_rates[sum(depths[:2]):sum(depths[:3])], stride=1)
        self.stage4 = self.make_stage(block, depths[3], dims[3], drop_path=drop_path_rates[sum(depths[:3]):sum(depths[:4])], stride=1)
        self.stages.append(self.stage1)
        self.stages.append(self.stage2)
        self.stages.append(self.stage3)
        self.stages.append(self.stage4)
        
    
        self.avgpool = nn.AdaptiveAvgPool2d((1,1))
        self.norm = nn.LayerNorm(2048, eps=1e-6) # final norm layer
        
        self.fc = nn.Linear(2048, num_classes)
    
    def forward(self, x):

        for i in range(4):
            x = self.downsample_layers[i](x)
            x = self.stages[i](x)
        
        #x = self.avgpool(x)
        x = self.norm(x.mean([-2, -1])) 
        
        x = x.reshape(x.shape[0], -1)
        x = self.fc(x)
        
        return x

    def make_stage(self, block, depth, dim, drop_path=[], stride=1):

        layers = []
    
        #first layer of each stage
        layers.append(block(self.inplanes, dim, drop_path=drop_path[0], stride=stride, first=True))
        self.inplanes = dim*self.expansion

        for i in range(depth-1):
            layers.append(block(self.inplanes, dim, drop_path=drop_path[i+1], stride=stride))

        return nn.Sequential(*layers)

# %%
model = ResNet()
summary(model, (3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2-1                   [-1, 64, 56, 56]          --
# |    |    └─Conv2d: 3-1                  [-1, 64, 112, 112]        9,408
# |    |    └─LayerNorm: 3-2               [-1, 64, 112, 112]        128
# |    |    └─GELU: 3-3                    [-1, 64, 112, 112]        --
# |    |    └─MaxPool2d: 3-4               [-1, 64, 56, 56]          --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2-2                   [-1, 256, 56, 56]         --
# ├─Sequential: 1-1                        [-1, 256, 56, 56]         (recursive)
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-5              [-1, 256, 56, 56]         73,984
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-3                   [-1, 256, 56, 56]         (recursive)
# |    |    └─Conv2d: 3-6                  [-1, 256, 56, 56]         (recursive)
# |    |    └─Conv2d: 3-7                  [-1, 64, 56, 56]          (recursive)
# |    |    └─BatchNorm2d: 3-8             [-1, 64, 56, 56]          (recursive)
# |    |    └─LayerNorm: 3-9               [-1, 64, 56, 56]          (recursive)
# |    |    └─Conv2d: 3-10                 [-1, 64, 56, 56]          (recursive)
# |    |    └─GELU: 3-11                   [-1, 64, 56, 56]          --
# |    |    └─Conv2d: 3-12                 [-1, 256, 56, 56]         (recursive)
# |    |    └─Identity: 3-13               [-1, 256, 56, 56]         --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-14             [-1, 256, 56, 56]         135,424
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-4                   [-1, 256, 56, 56]         (recursive)
# |    |    └─Conv2d: 3-15                 [-1, 64, 56, 56]          (recursive)
# |    |    └─BatchNorm2d: 3-16            [-1, 64, 56, 56]          (recursive)
# |    |    └─LayerNorm: 3-17              [-1, 64, 56, 56]          (recursive)
# |    |    └─Conv2d: 3-18                 [-1, 64, 56, 56]          (recursive)
# |    |    └─GELU: 3-19                   [-1, 64, 56, 56]          --
# |    |    └─Conv2d: 3-20                 [-1, 256, 56, 56]         (recursive)
# |    |    └─Identity: 3-21               [-1, 256, 56, 56]         --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-22             [-1, 256, 56, 56]         135,424
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-5                   [-1, 256, 56, 56]         (recursive)
# |    |    └─Conv2d: 3-23                 [-1, 64, 56, 56]          (recursive)
# |    |    └─BatchNorm2d: 3-24            [-1, 64, 56, 56]          (recursive)
# |    |    └─LayerNorm: 3-25              [-1, 64, 56, 56]          (recursive)
# |    |    └─Conv2d: 3-26                 [-1, 64, 56, 56]          (recursive)
# |    |    └─GELU: 3-27                   [-1, 64, 56, 56]          --
# |    |    └─Conv2d: 3-28                 [-1, 256, 56, 56]         (recursive)
# |    |    └─Identity: 3-29               [-1, 256, 56, 56]         --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2-6                   [-1, 256, 28, 28]         --
# |    |    └─LayerNorm: 3-30              [-1, 256, 56, 56]         512
# |    |    └─Conv2d: 3-31                 [-1, 256, 28, 28]         262,400
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2-7                   [-1, 512, 28, 28]         --
# ├─Sequential: 1-2                        [-1, 512, 28, 28]         (recursive)
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-32             [-1, 512, 28, 28]         377,344
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-8                   [-1, 512, 28, 28]         (recursive)
# |    |    └─Conv2d: 3-33                 [-1, 512, 28, 28]         (recursive)
# |    |    └─Conv2d: 3-34                 [-1, 128, 28, 28]         (recursive)
# |    |    └─BatchNorm2d: 3-35            [-1, 128, 28, 28]         (recursive)
# |    |    └─LayerNorm: 3-36              [-1, 128, 28, 28]         (recursive)
# |    |    └─Conv2d: 3-37                 [-1, 128, 28, 28]         (recursive)
# |    |    └─GELU: 3-38                   [-1, 128, 28, 28]         --
# |    |    └─Conv2d: 3-39                 [-1, 512, 28, 28]         (recursive)
# |    |    └─Identity: 3-40               [-1, 512, 28, 28]         --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-41             [-1, 512, 28, 28]         541,184
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-9                   [-1, 512, 28, 28]         (recursive)
# |    |    └─Conv2d: 3-42                 [-1, 128, 28, 28]         (recursive)
# |    |    └─BatchNorm2d: 3-43            [-1, 128, 28, 28]         (recursive)
# |    |    └─LayerNorm: 3-44              [-1, 128, 28, 28]         (recursive)
# |    |    └─Conv2d: 3-45                 [-1, 128, 28, 28]         (recursive)
# |    |    └─GELU: 3-46                   [-1, 128, 28, 28]         --
# |    |    └─Conv2d: 3-47                 [-1, 512, 28, 28]         (recursive)
# |    |    └─Identity: 3-48               [-1, 512, 28, 28]         --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-49             [-1, 512, 28, 28]         541,184
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-10                  [-1, 512, 28, 28]         (recursive)
# |    |    └─Conv2d: 3-50                 [-1, 128, 28, 28]         (recursive)
# |    |    └─BatchNorm2d: 3-51            [-1, 128, 28, 28]         (recursive)
# |    |    └─LayerNorm: 3-52              [-1, 128, 28, 28]         (recursive)
# |    |    └─Conv2d: 3-53                 [-1, 128, 28, 28]         (recursive)
# |    |    └─GELU: 3-54                   [-1, 128, 28, 28]         --
# |    |    └─Conv2d: 3-55                 [-1, 512, 28, 28]         (recursive)
# |    |    └─Identity: 3-56               [-1, 512, 28, 28]         --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-57             [-1, 512, 28, 28]         541,184
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-11                  [-1, 512, 28, 28]         (recursive)
# |    |    └─Conv2d: 3-58                 [-1, 128, 28, 28]         (recursive)
# |    |    └─BatchNorm2d: 3-59            [-1, 128, 28, 28]         (recursive)
# |    |    └─LayerNorm: 3-60              [-1, 128, 28, 28]         (recursive)
# |    |    └─Conv2d: 3-61                 [-1, 128, 28, 28]         (recursive)
# |    |    └─GELU: 3-62                   [-1, 128, 28, 28]         --
# |    |    └─Conv2d: 3-63                 [-1, 512, 28, 28]         (recursive)
# |    |    └─Identity: 3-64               [-1, 512, 28, 28]         --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2-12                  [-1, 512, 14, 14]         --
# |    |    └─LayerNorm: 3-65              [-1, 512, 28, 28]         1,024
# |    |    └─Conv2d: 3-66                 [-1, 512, 14, 14]         1,049,088
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2-13                  [-1, 1024, 14, 14]        --
# ├─Sequential: 1-3                        [-1, 1024, 14, 14]        (recursive)
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-67             [-1, 1024, 14, 14]        1,508,352
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-14                  [-1, 1024, 14, 14]        (recursive)
# |    |    └─Conv2d: 3-68                 [-1, 1024, 14, 14]        (recursive)
# |    |    └─Conv2d: 3-69                 [-1, 256, 14, 14]         (recursive)
# |    |    └─BatchNorm2d: 3-70            [-1, 256, 14, 14]         (recursive)
# |    |    └─LayerNorm: 3-71              [-1, 256, 14, 14]         (recursive)
# |    |    └─Conv2d: 3-72                 [-1, 256, 14, 14]         (recursive)
# |    |    └─GELU: 3-73                   [-1, 256, 14, 14]         --
# |    |    └─Conv2d: 3-74                 [-1, 1024, 14, 14]        (recursive)
# |    |    └─Identity: 3-75               [-1, 1024, 14, 14]        --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-76             [-1, 1024, 14, 14]        2,163,712
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-15                  [-1, 1024, 14, 14]        (recursive)
# |    |    └─Conv2d: 3-77                 [-1, 256, 14, 14]         (recursive)
# |    |    └─BatchNorm2d: 3-78            [-1, 256, 14, 14]         (recursive)
# |    |    └─LayerNorm: 3-79              [-1, 256, 14, 14]         (recursive)
# |    |    └─Conv2d: 3-80                 [-1, 256, 14, 14]         (recursive)
# |    |    └─GELU: 3-81                   [-1, 256, 14, 14]         --
# |    |    └─Conv2d: 3-82                 [-1, 1024, 14, 14]        (recursive)
# |    |    └─Identity: 3-83               [-1, 1024, 14, 14]        --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-84             [-1, 1024, 14, 14]        2,163,712
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-16                  [-1, 1024, 14, 14]        (recursive)
# |    |    └─Conv2d: 3-85                 [-1, 256, 14, 14]         (recursive)
# |    |    └─BatchNorm2d: 3-86            [-1, 256, 14, 14]         (recursive)
# |    |    └─LayerNorm: 3-87              [-1, 256, 14, 14]         (recursive)
# |    |    └─Conv2d: 3-88                 [-1, 256, 14, 14]         (recursive)
# |    |    └─GELU: 3-89                   [-1, 256, 14, 14]         --
# |    |    └─Conv2d: 3-90                 [-1, 1024, 14, 14]        (recursive)
# |    |    └─Identity: 3-91               [-1, 1024, 14, 14]        --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-92             [-1, 1024, 14, 14]        2,163,712
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-17                  [-1, 1024, 14, 14]        (recursive)
# |    |    └─Conv2d: 3-93                 [-1, 256, 14, 14]         (recursive)
# |    |    └─BatchNorm2d: 3-94            [-1, 256, 14, 14]         (recursive)
# |    |    └─LayerNorm: 3-95              [-1, 256, 14, 14]         (recursive)
# |    |    └─Conv2d: 3-96                 [-1, 256, 14, 14]         (recursive)
# |    |    └─GELU: 3-97                   [-1, 256, 14, 14]         --
# |    |    └─Conv2d: 3-98                 [-1, 1024, 14, 14]        (recursive)
# |    |    └─Identity: 3-99               [-1, 1024, 14, 14]        --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-100            [-1, 1024, 14, 14]        2,163,712
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-18                  [-1, 1024, 14, 14]        (recursive)
# |    |    └─Conv2d: 3-101                [-1, 256, 14, 14]         (recursive)
# |    |    └─BatchNorm2d: 3-102           [-1, 256, 14, 14]         (recursive)
# |    |    └─LayerNorm: 3-103             [-1, 256, 14, 14]         (recursive)
# |    |    └─Conv2d: 3-104                [-1, 256, 14, 14]         (recursive)
# |    |    └─GELU: 3-105                  [-1, 256, 14, 14]         --
# |    |    └─Conv2d: 3-106                [-1, 1024, 14, 14]        (recursive)
# |    |    └─Identity: 3-107              [-1, 1024, 14, 14]        --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-108            [-1, 1024, 14, 14]        2,163,712
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-19                  [-1, 1024, 14, 14]        (recursive)
# |    |    └─Conv2d: 3-109                [-1, 256, 14, 14]         (recursive)
# |    |    └─BatchNorm2d: 3-110           [-1, 256, 14, 14]         (recursive)
# |    |    └─LayerNorm: 3-111             [-1, 256, 14, 14]         (recursive)
# |    |    └─Conv2d: 3-112                [-1, 256, 14, 14]         (recursive)
# |    |    └─GELU: 3-113                  [-1, 256, 14, 14]         --
# |    |    └─Conv2d: 3-114                [-1, 1024, 14, 14]        (recursive)
# |    |    └─Identity: 3-115              [-1, 1024, 14, 14]        --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2-20                  [-1, 1024, 7, 7]          --
# |    |    └─LayerNorm: 3-116             [-1, 1024, 14, 14]        2,048
# |    |    └─Conv2d: 3-117                [-1, 1024, 7, 7]          4,195,328
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2-21                  [-1, 2048, 7, 7]          --
# ├─Sequential: 1-4                        [-1, 2048, 7, 7]          (recursive)
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-118            [-1, 2048, 7, 7]          6,031,360
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-22                  [-1, 2048, 7, 7]          (recursive)
# |    |    └─Conv2d: 3-119                [-1, 2048, 7, 7]          (recursive)
# |    |    └─Conv2d: 3-120                [-1, 512, 7, 7]           (recursive)
# |    |    └─BatchNorm2d: 3-121           [-1, 512, 7, 7]           (recursive)
# |    |    └─LayerNorm: 3-122             [-1, 512, 7, 7]           (recursive)
# |    |    └─Conv2d: 3-123                [-1, 512, 7, 7]           (recursive)
# |    |    └─GELU: 3-124                  [-1, 512, 7, 7]           --
# |    |    └─Conv2d: 3-125                [-1, 2048, 7, 7]          (recursive)
# |    |    └─Identity: 3-126              [-1, 2048, 7, 7]          --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-127            [-1, 2048, 7, 7]          8,652,800
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-23                  [-1, 2048, 7, 7]          (recursive)
# |    |    └─Conv2d: 3-128                [-1, 512, 7, 7]           (recursive)
# |    |    └─BatchNorm2d: 3-129           [-1, 512, 7, 7]           (recursive)
# |    |    └─LayerNorm: 3-130             [-1, 512, 7, 7]           (recursive)
# |    |    └─Conv2d: 3-131                [-1, 512, 7, 7]           (recursive)
# |    |    └─GELU: 3-132                  [-1, 512, 7, 7]           --
# |    |    └─Conv2d: 3-133                [-1, 2048, 7, 7]          (recursive)
# |    |    └─Identity: 3-134              [-1, 2048, 7, 7]          --
# ├─ModuleList: 1                          []                        --
# |    └─Sequential: 2                     []                        --
# |    |    └─Bottleneck: 3-135            [-1, 2048, 7, 7]          8,652,800
# ├─Sequential: 1                          []                        --
# |    └─Bottleneck: 2-24                  [-1, 2048, 7, 7]          (recursive)
# |    |    └─Conv2d: 3-136                [-1, 512, 7, 7]           (recursive)
# |    |    └─BatchNorm2d: 3-137           [-1, 512, 7, 7]           (recursive)
# |    |    └─LayerNorm: 3-138             [-1, 512, 7, 7]           (recursive)
# |    |    └─Conv2d: 3-139                [-1, 512, 7, 7]           (recursive)
# |    |    └─GELU: 3-140                  [-1, 512, 7, 7]           --
# |    |    └─Conv2d: 3-141                [-1, 2048, 7, 7]          (recursive)
# |    |    └─Identity: 3-142              [-1, 2048, 7, 7]          --
# ├─LayerNorm: 1-5                         [-1, 2048]                4,096
# ├─Linear: 1-6                            [-1, 7000]                14,343,000
# ==========================================================================================
# Total params: 57,876,632
# Trainable params: 57,876,632
# Non-trainable params: 0
# Total mult-adds (G): 8.38
# ==========================================================================================
# Input size (MB): 0.57
# Forward/backward pass size (MB): 121.42
# Params size (MB): 220.78
# Estimated Total Size (MB): 342.78
# ==========================================================================================
